# %% [markdown]
# # Visualizing an image from the dataset

# %%
# visualize images using opencv
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

filepath = "/home/rmacher/Perception_8930/data/sets/nuscenes/samples/CAM_FRONT/n008-2018-08-01-15-16-36-0400__CAM_FRONT__1533151604012404.jpg"

img = mpimg.imread(filepath)
plt.imshow(img)
